# %% [markdown]
# # EDA Basics - Chai Sales
# First look at the dataset before changing anything.

# %%
import pandas as pd

df = pd.read_csv("chai_sales.csv")
df.head()

# %% [markdown]
# ## Basic shape and columns

# %%
print("Rows and columns:", df.shape)
print("\nColumns:")
print(df.columns.tolist())

# %% [markdown]
# ## Data types and missing values

# %%
df.info()
print("\nMissing values:")
print(df.isnull().sum())

# %% [markdown]
# ## Numerical summary

# %%
df.describe()

# %% [markdown]
# ## Categorical summary

# %%
df.describe(include="object")

# %% [markdown]
# ## Quick category checks

# %%
print(df["chai_type"].value_counts())
print("\nCities:", df["city"].unique())
print("\nPayment methods:", df["payment_method"].unique())
